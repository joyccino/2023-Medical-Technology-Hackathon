# %% [markdown]
# <a href="https://colab.research.google.com/github/joyccino/2023-Medical-Technology-Hackathon/blob/main/Joycelyn/1_Exploring_Binary_and_Categorical_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring Binary and Categorical Data

# %%
# !git clone https://github.com/gedeck/practical-statistics-for-data-scientists.git
# !pip install wquantiles
# Out:
# fatal: destination path 'practical-statistics-for-data-scientists' already exists and is not an empty directory.
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# %matplotlib inline

from pathlib import Path

import pandas as pd
import numpy as np
from scipy.stats import trim_mean
from statsmodels import robust
import wquantiles

import seaborn as sns
import matplotlib.pylab as plt

# %%
STATE_CSV = '/content/practical-statistics-for-data-scientists/data/state.csv'
state = pd.read_csv(STATE_CSV)
AIRPORT_DELAYS_CSV = "/content/practical-statistics-for-data-scientists/data/dfw_airline.csv"

# %%
# Table 1-6
dfw = pd.read_csv(AIRPORT_DELAYS_CSV)
print(100 * dfw / dfw.values.sum())
# Out:
#      Carrier        ATC   Weather  Security    Inbound
# 0  23.022989  30.400781  4.025214  0.122937  42.428079

# %%
# Pandas also supports bar charts for displaying a single categorical variable.
ax = dfw.transpose().plot.bar(figsize=(4, 4), legend=False)
ax.set_xlabel('Cause of delay')
ax.set_ylabel('Count')

plt.tight_layout()
plt.show()
